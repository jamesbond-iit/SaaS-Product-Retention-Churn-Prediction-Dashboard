# %% [markdown]
# # SaaS Product Retention & Churn Prediction Dashboard
# End-to-end product analytics: cohort retention, LTV/CAC, power-user identification and churn prediction.

# %%
import pandas as pd
df=pd.read_csv("../data/saas_users_12k.csv",parse_dates=["signup_date","churn_date"])
df.head()

# %% [markdown]
# ## Cohort retention
# Group users by signup month and measure active users by months since signup.

# %%
events=pd.read_csv("../data/saas_events.csv",parse_dates=["event_date"])
events.head()

# %% [markdown]
# ## Churn model
# Train logistic regression using engagement and adoption features. Evaluate using ROC-AUC and inspect coefficients for interpretability.

# %%
# See notebooks/analysis.py for the reproducible modeling pipeline.
